# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources in the README.md file
# - Happy learning!

# %%
# Import reduce from functools, numpy and pandas
from functools import reduce
import numpy
import pandas

# %% [markdown]
# # Challenge 1 - Mapping
#
# #### We will use the map function to clean up words in a book.
#
# In the following cell, we will read a text file containing the book The Prophet by Khalil Gibran.

# %%
# Run this code:

location = '../data/58585-0.txt'
with open(location, 'r', encoding="utf8") as f:
    prophet = f.read().split(' ')

# %%
len(prophet)
# Out:
# 13637

# %% [markdown]
# #### Let's remove the first 568 words since they contain information about the book but are not part of the book itself.
#
# Do this by removing from `prophet` elements 0 through 567 of the list (you can also do this by keeping elements 568 through the last element).

# %%
filtered_list = list (filter (lambda x: prophet.index(x) >=568, prophet ))

# %% [markdown]
# If you look through the words, you will find that many words have a reference attached to them. For example, let's look at words 1 through 10.

# %%
print(filtered_list[0:10])
# Out:
# ['PROPHET\n\n|Almustafa,', 'the{7}', 'chosen', 'the\nbeloved,', 'who', 'was', 'dawn', 'unto', 'own\nday,', 'had']

# %% [markdown]
# #### The next step is to create a function that will remove references.
#
# We will do this by splitting the string on the `{` character and keeping only the part before this character. Write your function below.

# %%
def reference(x):
    '''
    Input: A string
    Output: The string with references removed
    
    Example:
    Input: 'the{7}'
    Output: 'the'
    '''
    
    # your code here

# %%
# your code here

# %% [markdown]
# Now that we have our function, use the `map()` function to apply this function to our book, The Prophet. Return the resulting list to a new list called `prophet_reference`.

# %%
prophet_reference = list (map (lambda x: reference (x), filtered_list))

# %% [markdown]
# Another thing you may have noticed is that some words contain a line break. Let's write a function to split those words. Our function will return the string split on the character `\n`. Write your function in the cell below.

# %%
def line_break(x):
    '''
    Input: A string
    Output: A list of strings split on the line break (\n) character
        
    Example:
    Input: 'the\nbeloved'
    Output: ['the', 'beloved']
    '''
    
    # your code here

# %% [markdown]
# Apply the `line_break` function to the `prophet_reference` list. Name the new list `prophet_line`.

# %%
prophet_line = list (map (lambda x: line_break (x), prophet_reference))
prophet_line
# Out:
# [['PROPHET', '', '|Almustafa,'],
#  ['the'],
#  ['chosen'],
#  ['the', 'beloved,'],
#  ['who'],
#  ['was'],
#  ['dawn'],
#  ['unto'],
#  ['own', 'day,'],
#  ['had'],
#  ['waited'],
#  ['twelve'],
#  ['years'],
#  ['city', 'of'],
#  ['Orphalese'],
#  ['ship'],
#  ['that'],
#  ['was'],
#  ['to', 'return'],
#  ['bear'],
#  ['him'],
#  ['back'],
#  ['isle'],
#  ['of', 'his'],
#  ['birth.', '', 'And'],
#  ['twelfth'],
#  ['year,'],
#  ['on'],
#  ['seventh', 'day'],
#  ['Ielool,'],
#  ['month'],
#  ['reaping,'],
#  ['he', 'climbed'],
#  ['hill'],
#  ['without'],
#  ['city'],
#  ['walls', 'and'],
#  ['looked'],
#  ['seaward;'],
#  ['beheld'],
#  ['his', 'ship'],
#  ['coming'],
#  ['mist.', '', 'Then'],
#  ['gates'],
#  ['heart'],
#  ['flung', 'open,'],
#  ['joy'],
#  ['flew'],
#  ['far'],
#  ['over'],
#  ['sea.', 'And'],
#  ['closed'],
#  ['eyes'],
#  ['prayed'],
#  ['the', 'silences'],
#  ['soul.', '', '*****', '', 'But'],
#  ['as'],
#  ['descended'],
#  ['hill,'],
#  ['sadness', 'came'],
#  ['upon'],
#  ['him,'],
#  ['thought'],
#  ['his', 'heart:', '', 'How'],
#  ['shall'],
#  ['I'],
#  ['go'],
#  ['peace'],
#  ['without', 'sorrow?'],
#  ['Nay,'],
#  ['without'],
#  ['wound'],
#  ['the', 'spirit'],
#  ['shall'],
#  ['I'],
#  ['leave'],
#  ['city.'],
#  [''],
#  ['days'],
#  ['pain'],
#  ['I'],
#  ['have'],
#  ['spent', 'within'],
#  ['its'],
#  ['walls,'],
#  ['long'],
#  ['the', 'nights'],
#  ['aloneness;'],
#  ['who'],
#  ['can'],
#  ['depart', 'from'],
#  ['pain'],
#  ['aloneness'],
#  ['without', 'regret?', '', 'Too'],
#  ['many'],
#  ['fragments'],
#  ['spirit'],
#  ['have'],
#  ['I', 'scattered'],
#  ['these'],
#  ['streets,'],
#  ['too'],
#  ['many', 'are'],
#  ['children'],
#  ['my'],
#  ['longing'],
#  ['that'],
#  ['walk', 'naked'],
#  ['among'],
#  ['these'],
#  ['hills,'],
#  ['I'],
#  ['cannot', 'withdraw'],
#  ['them'],
#  ['without'],
#  ['burden'],
#  ['and', 'an'],
#  ['ache.', '', 'It'],
#  ['garment'],
#  ['I'],
#  ['cast'],
#  ['off'],
#  ['this', 'day,'],
#  ['skin'],
#  ['that'],
#  ['I'],
#  ['tear'],
#  ['my'],
#  ['own', 'hands.', '', 'Nor'],
#  ['thought'],
#  ['I'],
#  ['leave'],
#  ['behind'],
#  ['me,', 'but'],
#  ['heart'],
#  ['made'],
#  ['sweet'],
#  ['hunger'],
#  ['and', 'with'],
#  ['thirst.', '', '*****', '', 'Yet'],
#  ['I'],
#  ['cannot'],
#  ['tarry'],
#  ['longer.', '', 'The'],
#  ['sea'],
#  ['that'],
#  ['calls'],
#  ['things'],
#  ['unto'],
#  ['her', 'calls'],
#  ['me,'],
#  ['I'],
#  ['must'],
#  ['embark.', '', 'For'],
#  ['stay,'],
#  ['though'],
#  ['hours'],
#  ['burn'],
#  ['in', 'the'],
#  ['night,'],
#  ['freeze'],
#  ['crystallize', 'and'],
#  ['be'],
#  ['bound'],
#  ['mould.', '', 'Fain'],
#  ['would'],
#  ['I'],
#  ['take'],
#  ['me'],
#  ['that'],
#  ['is', 'here.'],
#  ['But'],
#  ['how'],
#  ['shall'],
#  ['I?', '', 'A'],
#  ['voice'],
#  ['cannot'],
#  ['carry'],
#  ['tongue'],
#  ['and', ''],
#  ['lips'],
#  ['that'],
#  ['gave'],
#  ['wings.'],
#  ['Alone', 'must'],
#  ['seek'],
#  ['ether.', '', 'And'],
#  ['alone'],
#  ['without'],
#  ['nest'],
#  ['shall'],
#  ['the', 'eagle'],
#  ['fly'],
#  ['across'],
#  ['sun.', '', '*****', '', 'Now'],
#  ['when'],
#  ['reached'],
#  ['foot'],
#  ['the', 'hill,'],
#  ['turned'],
#  ['again'],
#  ['towards'],
#  ['sea,', 'and'],
#  ['saw'],
#  ['ship'],
#  ['approaching'],
#  ['the', 'harbour,'],
#  ['upon'],
#  ['her'],
#  ['prow'],
#  ['mariners,', 'the'],
#  ['men'],
#  ['own'],
#  ['land.', '', 'And'],
#  ['soul'],
#  ['cried'],
#  ['out'],
#  ['them,'],
#  ['he', 'said:', '', 'Sons'],
#  ['my'],
#  ['ancient'],
#  ['mother,'],
#  ['riders'],
#  ['of', 'the'],
#  ['tides,', '', 'How'],
#  ['often'],
#  ['have'],
#  ['sailed'],
#  ['my'],
#  ['dreams.', 'And'],
#  ['now'],
#  ['come'],
#  ['my'],
#  ['awakening,'],
#  ['which', 'is'],
#  ['my'],
#  ['deeper'],
#  ['dream.', '', 'Ready'],
#  ['am'],
#  ['I'],
#  ['go,'],
#  ['my'],
#  ['eagerness'],
#  ['with', 'sails'],
#  ['full'],
#  ['awaits'],
#  ['wind.', '', 'Only'],
#  ['another'],
#  ['breath'],
#  ['will'],
#  ['I'],
#  ['breathe'],
#  ['in', 'this'],
#  ['still'],
#  ['air,'],
#  ['only'],
#  ['another'],
#  ['loving'],
#  ['look', 'cast'],
#  ['backward,', '', 'And'],
#  ['then'],
#  ['I'],
#  ['shall'],
#  ['stand'],
#  ['among'],
#  ['you,'],
#  ['a', 'seafarer'],
#  ['among'],
#  ['seafarers.'],
#  [''],
#  ['you,', 'vast'],
#  ['sea,'],
#  ['sleepless'],
#  ['mother,', '', 'Who'],
#  ['alone'],
#  ['peace'],
#  ['freedom'],
#  ['the', 'river'],
#  ['stream,', '', 'Only'],
#  ['another'],
#  ['winding'],
#  ['will'],
#  ['stream', 'make,'],
#  ['only'],
#  ['another'],
#  ['murmur'],
#  ['glade,', '', 'And'],
#  ['then'],
#  ['shall'],
#  ['I'],
#  ['come'],
#  ['you,'],
#  ['a', 'boundless'],
#  ['drop'],
#  ['boundless'],
#  ['ocean.', '', '*****', '', 'And'],
#  ['as'],
#  ['walked'],
#  ['saw'],
#  ['afar'],
#  ['men', 'and'],
#  ['women'],
#  ['leaving'],
#  ['their'],
#  ['fields'],
#  ['their', 'vineyards'],
#  ['hastening'],
#  ['towards'],
#  ['city', 'gates.', '', 'And'],
#  ['heard'],
#  ['their'],
#  ['voices'],
#  ['calling'],
#  ['his', 'name,'],
#  ['shouting'],
#  ['field'],
#  ['field', 'telling'],
#  ['one'],
#  ['another'],
#  ['coming'],
#  ['his', 'ship.', '', 'And'],
#  ['said'],
#  ['himself:', '', 'Shall'],
#  ['day'],
#  ['parting'],
#  ['be'],
#  ['day'],
#  ['of', 'gathering?', '', 'And'],
#  ['shall'],
#  ['be'],
#  ['said'],
#  ['that'],
#  ['my'],
#  ['eve'],
#  ['was'],
#  ['in', 'truth'],
#  ['my'],
#  ['dawn?', '', 'And'],
#  ['what'],
#  ['shall'],
#  ['I'],
#  ['unto'],
#  ['him'],
#  ['who'],
#  ['has', 'left'],
#  ['plough'],
#  ['midfurrow,'],
#  ['to', 'him'],
#  ['who'],
#  ['has'],
#  ['stopped'],
#  ['wheel'],
#  ['his', 'winepress?'],
#  [''],
#  ['my'],
#  ['heart'],
#  ['become'],
#  ['a', 'tree'],
#  ['heavy-laden'],
#  ['fruit'],
#  ['that'],
#  ['I'],
#  ['may', 'gather'],
#  ['unto'],
#  ['them?', '', 'And'],
#  ['shall'],
#  ['my'],
#  ['desires'],
#  ['flow'],
#  ['like'],
#  ['a', 'fountain'],
#  ['that'],
#  ['I'],
#  ['fill'],
#  ['their'],
#  ['cups?', '', 'Am'],
#  ['I'],
#  ['harp'],
#  ['that'],
#  ['hand'],
#  ['mighty', 'may'],
#  ['touch'],
#  ['me,'],
#  ['flute'],
#  ['that'],
#  ['breath', 'may'],
#  ['pass'],
#  ['through'],
#  ['me?', '', 'A'],
#  ['seeker'],
#  ['silences'],
#  ['am'],
#  ['I,'],
#  ['what', 'treasure'],
#  ['have'],
#  ['I'],
#  ['found'],
#  ['silences'],
#  ['that'],
#  ['I', 'may'],
#  ['dispense'],
#  ['confidence?', '', 'If'],
#  ['my'],
#  ['day'],
#  ['harvest,'],
#  ['what', 'fields'],
#  ['have'],
#  ['I'],
#  ['sowed'],
#  ['seed,'],
#  ['in', 'what'],
#  ['unremembered'],
#  ['seasons?', '', 'If'],
#  ['indeed'],
#  ['be'],
#  ['hour'],
#  ['which'],
#  ['I', 'lift'],
#  ['up'],
#  ['my'],
#  ['lantern,'],
#  ['my'],
#  ['flame', 'that'],
#  ['shall'],
#  ['burn'],
#  ['therein.', '', 'Empty'],
#  ['dark'],
#  ['shall'],
#  ['I'],
#  ['raise'],
#  ['my'],
#  ['lantern,', '', 'And'],
#  ['guardian'],
#  ['night'],
#  ['shall'],
#  ['fill', 'it'],
#  ['oil'],
#  ['shall'],
#  ['light'],
#  ['also.', '', '*****', '', 'These'],
#  ['things'],
#  ['said'],
#  ['words.'],
#  ['But'],
#  ['much', 'in'],
#  ['heart'],
#  ['remained'],
#  ['unsaid.'],
#  [''],
#  ['speak'],
#  ['deeper', 'secret.', '', '*****', '', '[Illustration:'],
#  ['0020]', '', 'And'],
#  ['when'],
#  ['entered'],
#  ['into'],
#  ['city'],
#  ['all', 'the'],
#  ['people'],
#  ['meet'],
#  ['him,'],
#  ['they', 'were'],
#  ['crying'],
#  ['out'],
#  ['him'],
#  ['as'],
#  ['one', 'voice.', '', 'And'],
#  ['elders'],
#  ['city'],
#  ['stood'],
#  ['forth', 'and'],
#  ['said:', '', 'Go'],
#  ['yet'],
#  ['us.', '', 'A'],
#  ['noontide'],
#  ['have'],
#  ['been'],
#  ['our', 'twilight,'],
#  ['your'],
#  ['youth'],
#  ['has'],
#  ['given'],
#  ['us', 'dreams'],
#  ['dream.', '', 'No'],
#  ['stranger'],
#  ['among'],
#  ['us,'],
#  ['nor', 'a'],
#  ['guest,'],
#  ['our'],
#  ['son'],
#  ['our'],
#  ['dearly', 'beloved.', '', 'Suffer'],
#  ['yet'],
#  ['our'],
#  ['eyes'],
#  ['hunger'],
#  ['for', 'your'],
#  ['face.', '', '*****', '', 'And'],
#  ['priests'],
#  ['priestesses'],
#  ['said', 'unto'],
#  ['him:', '', 'Let'],
#  ['waves'],
#  ['sea'],
#  ['separate'],
#  ['us', 'now,'],
#  ['years'],
#  ['have'],
#  ['spent'],
#  ['our', 'midst'],
#  ['become'],
#  ['memory.', '', 'You'],
#  ['have'],
#  ['walked'],
#  ['among'],
#  ['us'],
#  ['spirit,', ''],
#  ['your'],
#  ['shadow'],
#  ['has'],
#  ['been'],
#  ['light', 'upon'],
#  ['our'],
#  ['faces.', '', 'Much'],
#  ['have'],
#  ['we'],
#  ['loved'],
#  ['you.'],
#  ['But'],
#  ['speechless', 'was'],
#  ['our'],
#  ['love,'],
#  ['veils'],
#  ['has'],
#  ['been', 'veiled.', '', 'Yet'],
#  ['now'],
#  ['cries'],
#  ['aloud'],
#  ['unto'],
#  ['you,'],
#  ['and', 'would'],
#  ['stand'],
#  ['revealed'],
#  ['you.', '', 'And'],
#  ['ever'],
#  ['has'],
#  ['been'],
#  ['that'],
#  ['love'],
#  ['knows', 'not'],
#  ['its'],
#  ['own'],
#  ['depth'],
#  ['until'],
#  ['hour'],
#  ['of', 'separation.', '', '*****', '', 'And'],
#  ['others'],
#  ['also'],
#  ['entreated'],
#  ['him.', 'But'],
#  ['answered'],
#  ['them'],
#  ['not.'],
#  ['He'],
#  ['only'],
#  ['bent', 'his'],
#  ['head;'],
#  ['who'],
#  ['stood'],
#  ['near'],
#  ['saw', 'his'],
#  ['tears'],
#  ['falling'],
#  ['upon'],
#  ['breast.', '', 'And'],
#  ['people'],
#  ['proceeded'],
#  ['towards', 'the'],
#  ['square'],
#  ['temple.', '', 'And'],
#  ['there'],
#  ['out'],
#  ['sanctuary'],
#  ['a', 'woman'],
#  ['whose'],
#  ['name'],
#  ['was'],
#  ['Almitra.'],
#  ['And'],
#  ['she', 'was'],
#  ['seeress.', '', 'And'],
#  ['looked'],
#  ['upon'],
#  ['her'],
#  ['exceeding', 'tenderness,'],
#  ['was'],
#  ['she'],
#  ['who'],
#  ['had'],
#  ['first', 'sought'],
#  ['believed'],
#  ['him'],
#  ['when'],
#  ['had', 'been'],
#  ['day'],
#  ['their'],
#  ['city.'],
#  [''],
#  ['hailed'],
#  ['him,'],
#  ['saying:', '', 'Prophet'],
#  ['God,'],
#  ['quest'],
#  ['the', 'uttermost,'],
#  ['long'],
#  ['have'],
#  ['searched'],
#  ['the', 'distances'],
#  ['your'],
#  ['ship.', '', 'And'],
#  ['now'],
#  ['your'],
#  ['ship'],
#  ['has'],
#  ['come,'],
#  ['must', 'needs'],
#  ['go.', '', 'Deep'],
#  ['your'],
#  ['longing'],
#  ['land'],
#  ['of', 'your'],
#  ['memories'],
#  ['dwelling'],
#  ['place', 'of'],
#  ['your'],
#  ['greater'],
#  ['desires;'],
#  ['our'],
#  ['love', 'would'],
#  ['bind'],
#  ['nor'],
#  ['our'],
#  ['needs'],
#  ['hold', 'you.', '', 'Yet'],
#  ['we'],
#  ['ask'],
#  ['ere'],
#  ['leave'],
#  ['us,'],
#  ['that', 'you'],
#  ['speak'],
#  ['us'],
#  ['us'],
#  ['your', 'truth.', '', 'And'],
#  ['we'],
#  ['will'],
#  ['unto'],
#  ['our'],
#  ['children,', 'and'],
#  ['they'],
#  ['unto'],
#  ['their'],
#  ['children,'],
#  ['it', 'shall'],
#  ['perish.', '', 'In'],
#  ['your'],
#  ['aloneness'],
#  ['have'],
#  ['watched'],
#  ['with', 'our'],
#  ['days,'],
#  ['your'],
#  ['wakefulness'],
#  ['you', 'have'],
#  ['listened'],
#  ['weeping'],
#  ['the', 'laughter'],
#  ['our'],
#  ['sleep.', '', 'Now'],
#  ['therefore'],
#  ['disclose'],
#  ['us'],
#  ['ourselves,', 'and'],
#  ['tell'],
#  ['us'],
#  ['that'],
#  ['has'],
#  ['been'],
#  ['shown', 'you'],
#  ['that'],
#  ['which'],
#  ['between'],
#  ['birth'],
#  ['and', 'death.', '', '*****', '', 'And'],
#  ['answered,', '', 'People'],
#  ['Orphalese,'],
#  ['what'],
#  ['can'],
#  ['I', ''],
#  ['save'],
#  ['that'],
#  ['which'],
#  ['even'],
#  ['now', 'moving'],
#  ['within'],
#  ['your'],
#  ['souls?', '', '*****'],
#  ['*****', '', 'Then'],
#  ['said'],
#  ['Almitra,'],
#  ['Speak'],
#  ['us'],
#  ['of', '_Love_.', '', 'And'],
#  ['raised'],
#  ['head'],
#  ['looked'],
#  ['upon', 'the'],
#  ['people,'],
#  ['there'],
#  ['fell'],
#  ['stillness', 'upon'],
#  ['them.'],
#  ['And'],
#  ['voice'],
#  ['he', 'said:', '', 'When'],
#  ['love'],
#  ['beckons'],
#  ['you,'],
#  ['follow'],
#  ['him,', '', 'Though'],
#  ['ways'],
#  ['hard'],
#  ['steep.', '', 'And'],
#  ['when'],
#  ['wings'],
#  ['enfold'],
#  ['yield'],
#  ['to', 'him,', '', 'Though'],
#  ['sword'],
#  ['hidden'],
#  ['among'],
#  ['his', 'pinions'],
#  ['wound'],
#  ['you.', '', 'And'],
#  ['when'],
#  ['speaks'],
#  ['believe'],
#  ['in', 'him,', '', 'Though'],
#  ['voice'],
#  ['shatter'],
#  ['your'],
#  ['dreams', 'as'],
#  ['north'],
#  ['wind'],
#  ['lays'],
#  ['waste'],
#  ['garden.', '', 'For'],
#  ['even'],
#  ['as'],
#  ['love'],
#  ['crowns'],
#  ['shall', 'he'],
#  ['crucify'],
#  ['you.'],
#  ['Even'],
#  ['as'],
#  ['your', 'growth'],
#  ['your'],
#  ['pruning.', '', 'Even'],
#  ['as'],
#  ['ascends'],
#  ['your'],
#  ['height'],
#  ['and', ''],
#  ['your'],
#  ['tenderest'],
#  ['branches', 'that'],
#  ['quiver'],
#  ['sun,', '', 'So'],
#  ['shall'],
#  ['descend'],
#  ['your'],
#  ['roots'],
#  ['and', 'shake'],
#  ['them'],
#  ['their'],
#  ['clinging'],
#  ['the', 'earth.', '', '*****', '', 'Like'],
#  ['sheaves'],
#  ['corn'],
#  ['gathers'],
#  ['unto', 'himself.', '', 'He'],
#  ['threshes'],
#  ['make'],
#  ['naked.', '', 'He'],
#  ['sifts'],
#  ['free'],
#  ['your', 'husks.', '', 'He'],
#  ['grinds'],
#  ['whiteness.', '', 'He'],
#  ['kneads'],
#  ['until'],
#  ['pliant;', '', 'And'],
#  ['then'],
#  ['assigns'],
#  ['sacred', 'fire,'],
#  ['that'],
#  ['become'],
#  ['sacred'],
#  ['bread', 'for'],
#  ['God’s'],
#  ['sacred'],
#  ['feast.', '', '*****', '', 'All'],
#  ['these'],
#  ['things'],
#  ['shall'],
#  ['love'],
#  ['do'],
#  ['unto'],
#  ['you', 'that'],
#  ['know'],
#  ['secrets'],
#  ['your', 'heart,'],
#  ['that'],
#  ['knowledge'],
#  ['become'],
#  ['a', 'fragment'],
#  ['Life’s'],
#  ['heart.', '', 'But'],
#  ['if'],
#  ['your'],
#  ['fear'],
#  ['would'],
#  ['seek'],
#  ['only', 'love’s'],
#  ['peace'],
#  ['love’s'],
#  ['pleasure,', '', 'Then'],
#  ['better'],
#  ['that'],
#  ['you', 'cover'],
#  [''],
#  ['nakedness'],
#  ['pass'],
#  ['out'],
#  ['of', 'love’s'],
#  ['threshing-floor,', '', 'Into'],
#  ['seasonless'],
#  ['you', 'shall'],
#  ['laugh,'],
#  ['your', 'laughter,'],
#  ['weep,'],
#  ['your', 'tears.', '', '*****', '', 'Love'],
#  ['gives'],
#  ['naught'],
#  ['itself'],
#  ['takes', 'naught'],
#  ['itself.', '', 'Love'],
#  ['possesses'],
#  ['nor'],
#  ['would'],
#  ['be', 'possessed;', '', 'For'],
#  ['love'],
#  ['sufficient'],
#  ['unto'],
#  ['love.', '', 'When'],
#  ['love'],
#  ['should'],
#  ['say,'],
#  ['“God', 'is'],
#  ['my'],
#  ['heart,”'],
#  ['rather,'],
#  ['“I'],
#  ['am'],
#  ['in', 'the'],
#  ['heart'],
#  ['God.”', '', 'And'],
#  ['think'],
#  ['can'],
#  ['direct'],
#  ['course', 'of'],
#  ['love,'],
#  ['love,'],
#  ['if'],
#  ['finds'],
#  ['you', 'worthy,'],
#  ['directs'],
#  ['your'],
#  ['course.', '', 'Love'],
#  ['has'],
#  ['desire'],
#  ['fulfil', 'itself.', '', 'But'],
#  ['if'],
#  ['love'],
#  ['must'],
#  ['needs'],
#  ['have', 'desires,'],
#  ['let'],
#  ['these'],
#  ['be'],
#  ['your'],
#  ['desires:', '', 'To'],
#  ['melt'],
#  ['be'],
#  ['like'],
#  ['running'],
#  ['brook'],
#  ['that', 'sings'],
#  ['its'],
#  ['melody'],
#  ['night.'],
#  [''],
#  ['pain'],
#  ['too'],
#  ['much'],
#  ['tenderness.', '', 'To'],
#  ['be'],
#  ['wounded'],
#  ['your'],
#  ['own'],
#  ['understanding', 'of'],
#  ['love;', '', 'And'],
#  ['bleed'],
#  ['willingly'],
#  ['joyfully.', '', 'To'],
#  ['wake'],
#  ['dawn'],
#  ['winged'],
#  ['heart'],
#  ['and', 'give'],
#  ['thanks'],
#  ['another'],
#  ['day'],
#  ['loving;', '', 'To'],
#  ['rest'],
#  ['noon'],
#  ['hour'],
#  ['meditate', 'love’s'],
#  ['ecstacy;', '', 'To'],
#  ['return'],
#  ['home'],
#  ['eventide'],
#  ['with', 'gratitude;', '', 'And'],
#  ['then'],
#  ['sleep'],
#  ['prayer'],
#  ['for', 'the'],
#  ['beloved'],
#  ['your'],
#  ['heart'],
#  ['song'],
#  ['of', 'praise'],
#  ['upon'],
#  ['your'],
#  ['lips.', '', '[Illustration:'],
#  ['0029]', '', '*****'],
#  ['*****', '', ''],
#  ['Almitra'],
#  ['spoke'],
#  ['again'],
#  ['said,', 'And'],
#  ['what'],
#  ['_Marriage_'],
#  ['master?', '', 'And'],
#  ['answered'],
#  ['saying:', '', 'You'],
#  ['born'],
#  ['together,'],
#  ['together'],
#  ['you', 'shall'],
#  ['be'],
#  ['forevermore.', '', 'You'],
#  ['shall'],
#  ['be'],
#  ['together'],
#  ['when'],
#  ['white', 'wings'],
#  ['death'],
#  ['scatter'],
#  ['your'],
#  ['days.', '', 'Aye,'],
#  ['shall'],
#  ['be'],
#  ['together'],
#  ['even'],
#  ['the', 'silent'],
#  ['memory'],
#  ['God.', '', 'But'],
#  ['let'],
#  ['there'],
#  ['be'],
#  ['spaces'],
#  ['your', 'togetherness,', '', 'And'],
#  ['let'],
#  ['winds'],
#  ['heavens'],
#  ['dance', 'between'],
#  ['you.', '', '*****', '', 'Love'],
#  ['one'],
#  ...]

# %% [markdown]
# If you look at the elements of `prophet_line`, you will see that the function returned lists and not strings. Our list is now a list of lists. Flatten the list using list comprehension. Assign this new list to `prophet_flat`.

# %%
prophet_flat = [i for sub in prophet_line for i in sub]
prophet_flat
# Out:
# ['PROPHET',
#  '',
#  '|Almustafa,',
#  'the',
#  'chosen',
#  'the',
#  'beloved,',
#  'who',
#  'was',
#  'dawn',
#  'unto',
#  'own',
#  'day,',
#  'had',
#  'waited',
#  'twelve',
#  'years',
#  'city',
#  'of',
#  'Orphalese',
#  'ship',
#  'that',
#  'was',
#  'to',
#  'return',
#  'bear',
#  'him',
#  'back',
#  'isle',
#  'of',
#  'his',
#  'birth.',
#  '',
#  'And',
#  'twelfth',
#  'year,',
#  'on',
#  'seventh',
#  'day',
#  'Ielool,',
#  'month',
#  'reaping,',
#  'he',
#  'climbed',
#  'hill',
#  'without',
#  'city',
#  'walls',
#  'and',
#  'looked',
#  'seaward;',
#  'beheld',
#  'his',
#  'ship',
#  'coming',
#  'mist.',
#  '',
#  'Then',
#  'gates',
#  'heart',
#  'flung',
#  'open,',
#  'joy',
#  'flew',
#  'far',
#  'over',
#  'sea.',
#  'And',
#  'closed',
#  'eyes',
#  'prayed',
#  'the',
#  'silences',
#  'soul.',
#  '',
#  '*****',
#  '',
#  'But',
#  'as',
#  'descended',
#  'hill,',
#  'sadness',
#  'came',
#  'upon',
#  'him,',
#  'thought',
#  'his',
#  'heart:',
#  '',
#  'How',
#  'shall',
#  'I',
#  'go',
#  'peace',
#  'without',
#  'sorrow?',
#  'Nay,',
#  'without',
#  'wound',
#  'the',
#  'spirit',
#  'shall',
#  'I',
#  'leave',
#  'city.',
#  '',
#  'days',
#  'pain',
#  'I',
#  'have',
#  'spent',
#  'within',
#  'its',
#  'walls,',
#  'long',
#  'the',
#  'nights',
#  'aloneness;',
#  'who',
#  'can',
#  'depart',
#  'from',
#  'pain',
#  'aloneness',
#  'without',
#  'regret?',
#  '',
#  'Too',
#  'many',
#  'fragments',
#  'spirit',
#  'have',
#  'I',
#  'scattered',
#  'these',
#  'streets,',
#  'too',
#  'many',
#  'are',
#  'children',
#  'my',
#  'longing',
#  'that',
#  'walk',
#  'naked',
#  'among',
#  'these',
#  'hills,',
#  'I',
#  'cannot',
#  'withdraw',
#  'them',
#  'without',
#  'burden',
#  'and',
#  'an',
#  'ache.',
#  '',
#  'It',
#  'garment',
#  'I',
#  'cast',
#  'off',
#  'this',
#  'day,',
#  'skin',
#  'that',
#  'I',
#  'tear',
#  'my',
#  'own',
#  'hands.',
#  '',
#  'Nor',
#  'thought',
#  'I',
#  'leave',
#  'behind',
#  'me,',
#  'but',
#  'heart',
#  'made',
#  'sweet',
#  'hunger',
#  'and',
#  'with',
#  'thirst.',
#  '',
#  '*****',
#  '',
#  'Yet',
#  'I',
#  'cannot',
#  'tarry',
#  'longer.',
#  '',
#  'The',
#  'sea',
#  'that',
#  'calls',
#  'things',
#  'unto',
#  'her',
#  'calls',
#  'me,',
#  'I',
#  'must',
#  'embark.',
#  '',
#  'For',
#  'stay,',
#  'though',
#  'hours',
#  'burn',
#  'in',
#  'the',
#  'night,',
#  'freeze',
#  'crystallize',
#  'and',
#  'be',
#  'bound',
#  'mould.',
#  '',
#  'Fain',
#  'would',
#  'I',
#  'take',
#  'me',
#  'that',
#  'is',
#  'here.',
#  'But',
#  'how',
#  'shall',
#  'I?',
#  '',
#  'A',
#  'voice',
#  'cannot',
#  'carry',
#  'tongue',
#  'and',
#  '',
#  'lips',
#  'that',
#  'gave',
#  'wings.',
#  'Alone',
#  'must',
#  'seek',
#  'ether.',
#  '',
#  'And',
#  'alone',
#  'without',
#  'nest',
#  'shall',
#  'the',
#  'eagle',
#  'fly',
#  'across',
#  'sun.',
#  '',
#  '*****',
#  '',
#  'Now',
#  'when',
#  'reached',
#  'foot',
#  'the',
#  'hill,',
#  'turned',
#  'again',
#  'towards',
#  'sea,',
#  'and',
#  'saw',
#  'ship',
#  'approaching',
#  'the',
#  'harbour,',
#  'upon',
#  'her',
#  'prow',
#  'mariners,',
#  'the',
#  'men',
#  'own',
#  'land.',
#  '',
#  'And',
#  'soul',
#  'cried',
#  'out',
#  'them,',
#  'he',
#  'said:',
#  '',
#  'Sons',
#  'my',
#  'ancient',
#  'mother,',
#  'riders',
#  'of',
#  'the',
#  'tides,',
#  '',
#  'How',
#  'often',
#  'have',
#  'sailed',
#  'my',
#  'dreams.',
#  'And',
#  'now',
#  'come',
#  'my',
#  'awakening,',
#  'which',
#  'is',
#  'my',
#  'deeper',
#  'dream.',
#  '',
#  'Ready',
#  'am',
#  'I',
#  'go,',
#  'my',
#  'eagerness',
#  'with',
#  'sails',
#  'full',
#  'awaits',
#  'wind.',
#  '',
#  'Only',
#  'another',
#  'breath',
#  'will',
#  'I',
#  'breathe',
#  'in',
#  'this',
#  'still',
#  'air,',
#  'only',
#  'another',
#  'loving',
#  'look',
#  'cast',
#  'backward,',
#  '',
#  'And',
#  'then',
#  'I',
#  'shall',
#  'stand',
#  'among',
#  'you,',
#  'a',
#  'seafarer',
#  'among',
#  'seafarers.',
#  '',
#  'you,',
#  'vast',
#  'sea,',
#  'sleepless',
#  'mother,',
#  '',
#  'Who',
#  'alone',
#  'peace',
#  'freedom',
#  'the',
#  'river',
#  'stream,',
#  '',
#  'Only',
#  'another',
#  'winding',
#  'will',
#  'stream',
#  'make,',
#  'only',
#  'another',
#  'murmur',
#  'glade,',
#  '',
#  'And',
#  'then',
#  'shall',
#  'I',
#  'come',
#  'you,',
#  'a',
#  'boundless',
#  'drop',
#  'boundless',
#  'ocean.',
#  '',
#  '*****',
#  '',
#  'And',
#  'as',
#  'walked',
#  'saw',
#  'afar',
#  'men',
#  'and',
#  'women',
#  'leaving',
#  'their',
#  'fields',
#  'their',
#  'vineyards',
#  'hastening',
#  'towards',
#  'city',
#  'gates.',
#  '',
#  'And',
#  'heard',
#  'their',
#  'voices',
#  'calling',
#  'his',
#  'name,',
#  'shouting',
#  'field',
#  'field',
#  'telling',
#  'one',
#  'another',
#  'coming',
#  'his',
#  'ship.',
#  '',
#  'And',
#  'said',
#  'himself:',
#  '',
#  'Shall',
#  'day',
#  'parting',
#  'be',
#  'day',
#  'of',
#  'gathering?',
#  '',
#  'And',
#  'shall',
#  'be',
#  'said',
#  'that',
#  'my',
#  'eve',
#  'was',
#  'in',
#  'truth',
#  'my',
#  'dawn?',
#  '',
#  'And',
#  'what',
#  'shall',
#  'I',
#  'unto',
#  'him',
#  'who',
#  'has',
#  'left',
#  'plough',
#  'midfurrow,',
#  'to',
#  'him',
#  'who',
#  'has',
#  'stopped',
#  'wheel',
#  'his',
#  'winepress?',
#  '',
#  'my',
#  'heart',
#  'become',
#  'a',
#  'tree',
#  'heavy-laden',
#  'fruit',
#  'that',
#  'I',
#  'may',
#  'gather',
#  'unto',
#  'them?',
#  '',
#  'And',
#  'shall',
#  'my',
#  'desires',
#  'flow',
#  'like',
#  'a',
#  'fountain',
#  'that',
#  'I',
#  'fill',
#  'their',
#  'cups?',
#  '',
#  'Am',
#  'I',
#  'harp',
#  'that',
#  'hand',
#  'mighty',
#  'may',
#  'touch',
#  'me,',
#  'flute',
#  'that',
#  'breath',
#  'may',
#  'pass',
#  'through',
#  'me?',
#  '',
#  'A',
#  'seeker',
#  'silences',
#  'am',
#  'I,',
#  'what',
#  'treasure',
#  'have',
#  'I',
#  'found',
#  'silences',
#  'that',
#  'I',
#  'may',
#  'dispense',
#  'confidence?',
#  '',
#  'If',
#  'my',
#  'day',
#  'harvest,',
#  'what',
#  'fields',
#  'have',
#  'I',
#  'sowed',
#  'seed,',
#  'in',
#  'what',
#  'unremembered',
#  'seasons?',
#  '',
#  'If',
#  'indeed',
#  'be',
#  'hour',
#  'which',
#  'I',
#  'lift',
#  'up',
#  'my',
#  'lantern,',
#  'my',
#  'flame',
#  'that',
#  'shall',
#  'burn',
#  'therein.',
#  '',
#  'Empty',
#  'dark',
#  'shall',
#  'I',
#  'raise',
#  'my',
#  'lantern,',
#  '',
#  'And',
#  'guardian',
#  'night',
#  'shall',
#  'fill',
#  'it',
#  'oil',
#  'shall',
#  'light',
#  'also.',
#  '',
#  '*****',
#  '',
#  'These',
#  'things',
#  'said',
#  'words.',
#  'But',
#  'much',
#  'in',
#  'heart',
#  'remained',
#  'unsaid.',
#  '',
#  'speak',
#  'deeper',
#  'secret.',
#  '',
#  '*****',
#  '',
#  '[Illustration:',
#  '0020]',
#  '',
#  'And',
#  'when',
#  'entered',
#  'into',
#  'city',
#  'all',
#  'the',
#  'people',
#  'meet',
#  'him,',
#  'they',
#  'were',
#  'crying',
#  'out',
#  'him',
#  'as',
#  'one',
#  'voice.',
#  '',
#  'And',
#  'elders',
#  'city',
#  'stood',
#  'forth',
#  'and',
#  'said:',
#  '',
#  'Go',
#  'yet',
#  'us.',
#  '',
#  'A',
#  'noontide',
#  'have',
#  'been',
#  'our',
#  'twilight,',
#  'your',
#  'youth',
#  'has',
#  'given',
#  'us',
#  'dreams',
#  'dream.',
#  '',
#  'No',
#  'stranger',
#  'among',
#  'us,',
#  'nor',
#  'a',
#  'guest,',
#  'our',
#  'son',
#  'our',
#  'dearly',
#  'beloved.',
#  '',
#  'Suffer',
#  'yet',
#  'our',
#  'eyes',
#  'hunger',
#  'for',
#  'your',
#  'face.',
#  '',
#  '*****',
#  '',
#  'And',
#  'priests',
#  'priestesses',
#  'said',
#  'unto',
#  'him:',
#  '',
#  'Let',
#  'waves',
#  'sea',
#  'separate',
#  'us',
#  'now,',
#  'years',
#  'have',
#  'spent',
#  'our',
#  'midst',
#  'become',
#  'memory.',
#  '',
#  'You',
#  'have',
#  'walked',
#  'among',
#  'us',
#  'spirit,',
#  '',
#  'your',
#  'shadow',
#  'has',
#  'been',
#  'light',
#  'upon',
#  'our',
#  'faces.',
#  '',
#  'Much',
#  'have',
#  'we',
#  'loved',
#  'you.',
#  'But',
#  'speechless',
#  'was',
#  'our',
#  'love,',
#  'veils',
#  'has',
#  'been',
#  'veiled.',
#  '',
#  'Yet',
#  'now',
#  'cries',
#  'aloud',
#  'unto',
#  'you,',
#  'and',
#  'would',
#  'stand',
#  'revealed',
#  'you.',
#  '',
#  'And',
#  'ever',
#  'has',
#  'been',
#  'that',
#  'love',
#  'knows',
#  'not',
#  'its',
#  'own',
#  'depth',
#  'until',
#  'hour',
#  'of',
#  'separation.',
#  '',
#  '*****',
#  '',
#  'And',
#  'others',
#  'also',
#  'entreated',
#  'him.',
#  'But',
#  'answered',
#  'them',
#  'not.',
#  'He',
#  'only',
#  'bent',
#  'his',
#  'head;',
#  'who',
#  'stood',
#  'near',
#  'saw',
#  'his',
#  'tears',
#  'falling',
#  'upon',
#  'breast.',
#  '',
#  'And',
#  'people',
#  'proceeded',
#  'towards',
#  'the',
#  'square',
#  'temple.',
#  '',
#  'And',
#  'there',
#  'out',
#  'sanctuary',
#  'a',
#  'woman',
#  'whose',
#  'name',
#  'was',
#  'Almitra.',
#  'And',
#  'she',
#  'was',
#  'seeress.',
#  '',
#  'And',
#  'looked',
#  'upon',
#  'her',
#  'exceeding',
#  'tenderness,',
#  'was',
#  'she',
#  'who',
#  'had',
#  'first',
#  'sought',
#  'believed',
#  'him',
#  'when',
#  'had',
#  'been',
#  'day',
#  'their',
#  'city.',
#  '',
#  'hailed',
#  'him,',
#  'saying:',
#  '',
#  'Prophet',
#  'God,',
#  'quest',
#  'the',
#  'uttermost,',
#  'long',
#  'have',
#  'searched',
#  'the',
#  'distances',
#  'your',
#  'ship.',
#  '',
#  'And',
#  'now',
#  'your',
#  'ship',
#  'has',
#  'come,',
#  'must',
#  'needs',
#  'go.',
#  '',
#  'Deep',
#  'your',
#  'longing',
#  'land',
#  'of',
#  'your',
#  'memories',
#  'dwelling',
#  'place',
#  'of',
#  'your',
#  'greater',
#  'desires;',
#  'our',
#  'love',
#  'would',
#  'bind',
#  'nor',
#  'our',
#  'needs',
#  'hold',
#  'you.',
#  '',
#  'Yet',
#  'we',
#  'ask',
#  'ere',
#  'leave',
#  'us,',
#  'that',
#  'you',
#  'speak',
#  'us',
#  'us',
#  'your',
#  'truth.',
#  '',
#  'And',
#  'we',
#  'will',
#  'unto',
#  'our',
#  'children,',
#  'and',
#  'they',
#  'unto',
#  'their',
#  'children,',
#  'it',
#  'shall',
#  'perish.',
#  '',
#  'In',
#  'your',
#  'aloneness',
#  'have',
#  'watched',
#  'with',
#  'our',
#  'days,',
#  'your',
#  'wakefulness',
#  'you',
#  'have',
#  'listened',
#  'weeping',
#  'the',
#  'laughter',
#  'our',
#  'sleep.',
#  '',
#  'Now',
#  'therefore',
#  'disclose',
#  'us',
#  'ourselves,',
#  'and',
#  'tell',
#  'us',
#  'that',
#  'has',
#  'been',
#  'shown',
#  'you',
#  'that',
#  'which',
#  'between',
#  'birth',
#  'and',
#  'death.',
#  '',
#  '*****',
#  '',
#  'And',
#  'answered,',
#  '',
#  'People',
#  'Orphalese,',
#  'what',
#  'can',
#  'I',
#  '',
#  'save',
#  'that',
#  'which',
#  'even',
#  'now',
#  'moving',
#  'within',
#  'your',
#  'souls?',
#  '',
#  '*****',
#  '*****',
#  '',
#  'Then',
#  'said',
#  'Almitra,',
#  'Speak',
#  'us',
#  'of',
#  '_Love_.',
#  '',
#  'And',
#  'raised',
#  'head',
#  'looked',
#  'upon',
#  'the',
#  'people,',
#  'there',
#  'fell',
#  'stillness',
#  'upon',
#  ...]

# %%
# your code here

# %% [markdown]
# # Challenge 2 - Filtering
#
# When printing out a few words from the book, we see that there are words that we may not want to keep if we choose to analyze the corpus of text. Below is a list of words that we would like to get rid of. Create a function that will return false if it contains a word from the list of words specified and true otherwise.

# %%
def word_filter(x):
   
    '''
    Input: A string
    Output: True the word is not in the specified list 
    and False if the word is in the list.
        
    Example:
    word list = ['and', 'the']
    Input: 'and'
    Output: False
    
    Input: 'John'
    Output: True
    '''
    
    word_list = ['and', 'the', 'a', 'an']
    
    if x in word_list:
        return False 
    return True

# %% [markdown]
# Use the `filter()` function to filter out the words speficied in the `word_filter()` function. Store the filtered list in the variable `prophet_filter`.

# %%
prophet_filter = list (filter (lambda x: word_filter (x), prophet_flat))
prophet_filter
# Out:
# ['PROPHET',
#  '',
#  '|Almustafa,',
#  'chosen',
#  'beloved,',
#  'who',
#  'was',
#  'dawn',
#  'unto',
#  'own',
#  'day,',
#  'had',
#  'waited',
#  'twelve',
#  'years',
#  'city',
#  'of',
#  'Orphalese',
#  'ship',
#  'that',
#  'was',
#  'to',
#  'return',
#  'bear',
#  'him',
#  'back',
#  'isle',
#  'of',
#  'his',
#  'birth.',
#  '',
#  'And',
#  'twelfth',
#  'year,',
#  'on',
#  'seventh',
#  'day',
#  'Ielool,',
#  'month',
#  'reaping,',
#  'he',
#  'climbed',
#  'hill',
#  'without',
#  'city',
#  'walls',
#  'looked',
#  'seaward;',
#  'beheld',
#  'his',
#  'ship',
#  'coming',
#  'mist.',
#  '',
#  'Then',
#  'gates',
#  'heart',
#  'flung',
#  'open,',
#  'joy',
#  'flew',
#  'far',
#  'over',
#  'sea.',
#  'And',
#  'closed',
#  'eyes',
#  'prayed',
#  'silences',
#  'soul.',
#  '',
#  '*****',
#  '',
#  'But',
#  'as',
#  'descended',
#  'hill,',
#  'sadness',
#  'came',
#  'upon',
#  'him,',
#  'thought',
#  'his',
#  'heart:',
#  '',
#  'How',
#  'shall',
#  'I',
#  'go',
#  'peace',
#  'without',
#  'sorrow?',
#  'Nay,',
#  'without',
#  'wound',
#  'spirit',
#  'shall',
#  'I',
#  'leave',
#  'city.',
#  '',
#  'days',
#  'pain',
#  'I',
#  'have',
#  'spent',
#  'within',
#  'its',
#  'walls,',
#  'long',
#  'nights',
#  'aloneness;',
#  'who',
#  'can',
#  'depart',
#  'from',
#  'pain',
#  'aloneness',
#  'without',
#  'regret?',
#  '',
#  'Too',
#  'many',
#  'fragments',
#  'spirit',
#  'have',
#  'I',
#  'scattered',
#  'these',
#  'streets,',
#  'too',
#  'many',
#  'are',
#  'children',
#  'my',
#  'longing',
#  'that',
#  'walk',
#  'naked',
#  'among',
#  'these',
#  'hills,',
#  'I',
#  'cannot',
#  'withdraw',
#  'them',
#  'without',
#  'burden',
#  'ache.',
#  '',
#  'It',
#  'garment',
#  'I',
#  'cast',
#  'off',
#  'this',
#  'day,',
#  'skin',
#  'that',
#  'I',
#  'tear',
#  'my',
#  'own',
#  'hands.',
#  '',
#  'Nor',
#  'thought',
#  'I',
#  'leave',
#  'behind',
#  'me,',
#  'but',
#  'heart',
#  'made',
#  'sweet',
#  'hunger',
#  'with',
#  'thirst.',
#  '',
#  '*****',
#  '',
#  'Yet',
#  'I',
#  'cannot',
#  'tarry',
#  'longer.',
#  '',
#  'The',
#  'sea',
#  'that',
#  'calls',
#  'things',
#  'unto',
#  'her',
#  'calls',
#  'me,',
#  'I',
#  'must',
#  'embark.',
#  '',
#  'For',
#  'stay,',
#  'though',
#  'hours',
#  'burn',
#  'in',
#  'night,',
#  'freeze',
#  'crystallize',
#  'be',
#  'bound',
#  'mould.',
#  '',
#  'Fain',
#  'would',
#  'I',
#  'take',
#  'me',
#  'that',
#  'is',
#  'here.',
#  'But',
#  'how',
#  'shall',
#  'I?',
#  '',
#  'A',
#  'voice',
#  'cannot',
#  'carry',
#  'tongue',
#  '',
#  'lips',
#  'that',
#  'gave',
#  'wings.',
#  'Alone',
#  'must',
#  'seek',
#  'ether.',
#  '',
#  'And',
#  'alone',
#  'without',
#  'nest',
#  'shall',
#  'eagle',
#  'fly',
#  'across',
#  'sun.',
#  '',
#  '*****',
#  '',
#  'Now',
#  'when',
#  'reached',
#  'foot',
#  'hill,',
#  'turned',
#  'again',
#  'towards',
#  'sea,',
#  'saw',
#  'ship',
#  'approaching',
#  'harbour,',
#  'upon',
#  'her',
#  'prow',
#  'mariners,',
#  'men',
#  'own',
#  'land.',
#  '',
#  'And',
#  'soul',
#  'cried',
#  'out',
#  'them,',
#  'he',
#  'said:',
#  '',
#  'Sons',
#  'my',
#  'ancient',
#  'mother,',
#  'riders',
#  'of',
#  'tides,',
#  '',
#  'How',
#  'often',
#  'have',
#  'sailed',
#  'my',
#  'dreams.',
#  'And',
#  'now',
#  'come',
#  'my',
#  'awakening,',
#  'which',
#  'is',
#  'my',
#  'deeper',
#  'dream.',
#  '',
#  'Ready',
#  'am',
#  'I',
#  'go,',
#  'my',
#  'eagerness',
#  'with',
#  'sails',
#  'full',
#  'awaits',
#  'wind.',
#  '',
#  'Only',
#  'another',
#  'breath',
#  'will',
#  'I',
#  'breathe',
#  'in',
#  'this',
#  'still',
#  'air,',
#  'only',
#  'another',
#  'loving',
#  'look',
#  'cast',
#  'backward,',
#  '',
#  'And',
#  'then',
#  'I',
#  'shall',
#  'stand',
#  'among',
#  'you,',
#  'seafarer',
#  'among',
#  'seafarers.',
#  '',
#  'you,',
#  'vast',
#  'sea,',
#  'sleepless',
#  'mother,',
#  '',
#  'Who',
#  'alone',
#  'peace',
#  'freedom',
#  'river',
#  'stream,',
#  '',
#  'Only',
#  'another',
#  'winding',
#  'will',
#  'stream',
#  'make,',
#  'only',
#  'another',
#  'murmur',
#  'glade,',
#  '',
#  'And',
#  'then',
#  'shall',
#  'I',
#  'come',
#  'you,',
#  'boundless',
#  'drop',
#  'boundless',
#  'ocean.',
#  '',
#  '*****',
#  '',
#  'And',
#  'as',
#  'walked',
#  'saw',
#  'afar',
#  'men',
#  'women',
#  'leaving',
#  'their',
#  'fields',
#  'their',
#  'vineyards',
#  'hastening',
#  'towards',
#  'city',
#  'gates.',
#  '',
#  'And',
#  'heard',
#  'their',
#  'voices',
#  'calling',
#  'his',
#  'name,',
#  'shouting',
#  'field',
#  'field',
#  'telling',
#  'one',
#  'another',
#  'coming',
#  'his',
#  'ship.',
#  '',
#  'And',
#  'said',
#  'himself:',
#  '',
#  'Shall',
#  'day',
#  'parting',
#  'be',
#  'day',
#  'of',
#  'gathering?',
#  '',
#  'And',
#  'shall',
#  'be',
#  'said',
#  'that',
#  'my',
#  'eve',
#  'was',
#  'in',
#  'truth',
#  'my',
#  'dawn?',
#  '',
#  'And',
#  'what',
#  'shall',
#  'I',
#  'unto',
#  'him',
#  'who',
#  'has',
#  'left',
#  'plough',
#  'midfurrow,',
#  'to',
#  'him',
#  'who',
#  'has',
#  'stopped',
#  'wheel',
#  'his',
#  'winepress?',
#  '',
#  'my',
#  'heart',
#  'become',
#  'tree',
#  'heavy-laden',
#  'fruit',
#  'that',
#  'I',
#  'may',
#  'gather',
#  'unto',
#  'them?',
#  '',
#  'And',
#  'shall',
#  'my',
#  'desires',
#  'flow',
#  'like',
#  'fountain',
#  'that',
#  'I',
#  'fill',
#  'their',
#  'cups?',
#  '',
#  'Am',
#  'I',
#  'harp',
#  'that',
#  'hand',
#  'mighty',
#  'may',
#  'touch',
#  'me,',
#  'flute',
#  'that',
#  'breath',
#  'may',
#  'pass',
#  'through',
#  'me?',
#  '',
#  'A',
#  'seeker',
#  'silences',
#  'am',
#  'I,',
#  'what',
#  'treasure',
#  'have',
#  'I',
#  'found',
#  'silences',
#  'that',
#  'I',
#  'may',
#  'dispense',
#  'confidence?',
#  '',
#  'If',
#  'my',
#  'day',
#  'harvest,',
#  'what',
#  'fields',
#  'have',
#  'I',
#  'sowed',
#  'seed,',
#  'in',
#  'what',
#  'unremembered',
#  'seasons?',
#  '',
#  'If',
#  'indeed',
#  'be',
#  'hour',
#  'which',
#  'I',
#  'lift',
#  'up',
#  'my',
#  'lantern,',
#  'my',
#  'flame',
#  'that',
#  'shall',
#  'burn',
#  'therein.',
#  '',
#  'Empty',
#  'dark',
#  'shall',
#  'I',
#  'raise',
#  'my',
#  'lantern,',
#  '',
#  'And',
#  'guardian',
#  'night',
#  'shall',
#  'fill',
#  'it',
#  'oil',
#  'shall',
#  'light',
#  'also.',
#  '',
#  '*****',
#  '',
#  'These',
#  'things',
#  'said',
#  'words.',
#  'But',
#  'much',
#  'in',
#  'heart',
#  'remained',
#  'unsaid.',
#  '',
#  'speak',
#  'deeper',
#  'secret.',
#  '',
#  '*****',
#  '',
#  '[Illustration:',
#  '0020]',
#  '',
#  'And',
#  'when',
#  'entered',
#  'into',
#  'city',
#  'all',
#  'people',
#  'meet',
#  'him,',
#  'they',
#  'were',
#  'crying',
#  'out',
#  'him',
#  'as',
#  'one',
#  'voice.',
#  '',
#  'And',
#  'elders',
#  'city',
#  'stood',
#  'forth',
#  'said:',
#  '',
#  'Go',
#  'yet',
#  'us.',
#  '',
#  'A',
#  'noontide',
#  'have',
#  'been',
#  'our',
#  'twilight,',
#  'your',
#  'youth',
#  'has',
#  'given',
#  'us',
#  'dreams',
#  'dream.',
#  '',
#  'No',
#  'stranger',
#  'among',
#  'us,',
#  'nor',
#  'guest,',
#  'our',
#  'son',
#  'our',
#  'dearly',
#  'beloved.',
#  '',
#  'Suffer',
#  'yet',
#  'our',
#  'eyes',
#  'hunger',
#  'for',
#  'your',
#  'face.',
#  '',
#  '*****',
#  '',
#  'And',
#  'priests',
#  'priestesses',
#  'said',
#  'unto',
#  'him:',
#  '',
#  'Let',
#  'waves',
#  'sea',
#  'separate',
#  'us',
#  'now,',
#  'years',
#  'have',
#  'spent',
#  'our',
#  'midst',
#  'become',
#  'memory.',
#  '',
#  'You',
#  'have',
#  'walked',
#  'among',
#  'us',
#  'spirit,',
#  '',
#  'your',
#  'shadow',
#  'has',
#  'been',
#  'light',
#  'upon',
#  'our',
#  'faces.',
#  '',
#  'Much',
#  'have',
#  'we',
#  'loved',
#  'you.',
#  'But',
#  'speechless',
#  'was',
#  'our',
#  'love,',
#  'veils',
#  'has',
#  'been',
#  'veiled.',
#  '',
#  'Yet',
#  'now',
#  'cries',
#  'aloud',
#  'unto',
#  'you,',
#  'would',
#  'stand',
#  'revealed',
#  'you.',
#  '',
#  'And',
#  'ever',
#  'has',
#  'been',
#  'that',
#  'love',
#  'knows',
#  'not',
#  'its',
#  'own',
#  'depth',
#  'until',
#  'hour',
#  'of',
#  'separation.',
#  '',
#  '*****',
#  '',
#  'And',
#  'others',
#  'also',
#  'entreated',
#  'him.',
#  'But',
#  'answered',
#  'them',
#  'not.',
#  'He',
#  'only',
#  'bent',
#  'his',
#  'head;',
#  'who',
#  'stood',
#  'near',
#  'saw',
#  'his',
#  'tears',
#  'falling',
#  'upon',
#  'breast.',
#  '',
#  'And',
#  'people',
#  'proceeded',
#  'towards',
#  'square',
#  'temple.',
#  '',
#  'And',
#  'there',
#  'out',
#  'sanctuary',
#  'woman',
#  'whose',
#  'name',
#  'was',
#  'Almitra.',
#  'And',
#  'she',
#  'was',
#  'seeress.',
#  '',
#  'And',
#  'looked',
#  'upon',
#  'her',
#  'exceeding',
#  'tenderness,',
#  'was',
#  'she',
#  'who',
#  'had',
#  'first',
#  'sought',
#  'believed',
#  'him',
#  'when',
#  'had',
#  'been',
#  'day',
#  'their',
#  'city.',
#  '',
#  'hailed',
#  'him,',
#  'saying:',
#  '',
#  'Prophet',
#  'God,',
#  'quest',
#  'uttermost,',
#  'long',
#  'have',
#  'searched',
#  'distances',
#  'your',
#  'ship.',
#  '',
#  'And',
#  'now',
#  'your',
#  'ship',
#  'has',
#  'come,',
#  'must',
#  'needs',
#  'go.',
#  '',
#  'Deep',
#  'your',
#  'longing',
#  'land',
#  'of',
#  'your',
#  'memories',
#  'dwelling',
#  'place',
#  'of',
#  'your',
#  'greater',
#  'desires;',
#  'our',
#  'love',
#  'would',
#  'bind',
#  'nor',
#  'our',
#  'needs',
#  'hold',
#  'you.',
#  '',
#  'Yet',
#  'we',
#  'ask',
#  'ere',
#  'leave',
#  'us,',
#  'that',
#  'you',
#  'speak',
#  'us',
#  'us',
#  'your',
#  'truth.',
#  '',
#  'And',
#  'we',
#  'will',
#  'unto',
#  'our',
#  'children,',
#  'they',
#  'unto',
#  'their',
#  'children,',
#  'it',
#  'shall',
#  'perish.',
#  '',
#  'In',
#  'your',
#  'aloneness',
#  'have',
#  'watched',
#  'with',
#  'our',
#  'days,',
#  'your',
#  'wakefulness',
#  'you',
#  'have',
#  'listened',
#  'weeping',
#  'laughter',
#  'our',
#  'sleep.',
#  '',
#  'Now',
#  'therefore',
#  'disclose',
#  'us',
#  'ourselves,',
#  'tell',
#  'us',
#  'that',
#  'has',
#  'been',
#  'shown',
#  'you',
#  'that',
#  'which',
#  'between',
#  'birth',
#  'death.',
#  '',
#  '*****',
#  '',
#  'And',
#  'answered,',
#  '',
#  'People',
#  'Orphalese,',
#  'what',
#  'can',
#  'I',
#  '',
#  'save',
#  'that',
#  'which',
#  'even',
#  'now',
#  'moving',
#  'within',
#  'your',
#  'souls?',
#  '',
#  '*****',
#  '*****',
#  '',
#  'Then',
#  'said',
#  'Almitra,',
#  'Speak',
#  'us',
#  'of',
#  '_Love_.',
#  '',
#  'And',
#  'raised',
#  'head',
#  'looked',
#  'upon',
#  'people,',
#  'there',
#  'fell',
#  'stillness',
#  'upon',
#  'them.',
#  'And',
#  'voice',
#  'he',
#  'said:',
#  '',
#  'When',
#  'love',
#  'beckons',
#  'you,',
#  'follow',
#  'him,',
#  '',
#  'Though',
#  'ways',
#  'hard',
#  'steep.',
#  '',
#  'And',
#  'when',
#  'wings',
#  'enfold',
#  'yield',
#  'to',
#  'him,',
#  '',
#  'Though',
#  'sword',
#  'hidden',
#  'among',
#  'his',
#  'pinions',
#  'wound',
#  'you.',
#  '',
#  'And',
#  'when',
#  ...]

# %% [markdown]
# # Bonus Challenge
#
# Rewrite the `word_filter` function above to not be case sensitive.

# %%
def word_filter_case(x):
   
    word_list = ['and', 'the', 'a', 'an']
    
    # your code here

# %% [markdown]
# # Challenge 3 - Reducing
#
# #### Now that we have significantly cleaned up our text corpus, let's use the `reduce()` function to put the words back together into one long string separated by spaces.
#
# We will start by writing a function that takes two strings and concatenates them together with a space between the two strings.

# %%
def concat_space(a, b):
    '''
    Input:Two strings
    Output: A single string separated by a space
        
    Example:
    Input: 'John', 'Smith'
    Output: 'John Smith'
    '''
    return a + ' ' + b
    # your code here

# %%
# your code here

# %% [markdown]
# Use the function above to reduce the text corpus in the list `prophet_filter` into a single string. Assign this new string to the variable `prophet_string`.

# %%
prophet_string = reduce(lambda x, y: concat_space(x, y), prophet_filter)
prophet_string
# Out:
# 'PROPHET  |Almustafa, chosen beloved, who was dawn unto own day, had waited twelve years city of Orphalese ship that was to return bear him back isle of his birth.  And twelfth year, on seventh day Ielool, month reaping, he climbed hill without city walls looked seaward; beheld his ship coming mist.  Then gates heart flung open, joy flew far over sea. And closed eyes prayed silences soul.  *****  But as descended hill, sadness came upon him, thought his heart:  How shall I go peace without sorrow? Nay, without wound spirit shall I leave city.  days pain I have spent within its walls, long nights aloneness; who can depart from pain aloneness without regret?  Too many fragments spirit have I scattered these streets, too many are children my longing that walk naked among these hills, I cannot withdraw them without burden ache.  It garment I cast off this day, skin that I tear my own hands.  Nor thought I leave behind me, but heart made sweet hunger with thirst.  *****  Yet I cannot tarry longer.  The sea that calls things unto her calls me, I must embark.  For stay, though hours burn in night, freeze crystallize be bound mould.  Fain would I take me that is here. But how shall I?  A voice cannot carry tongue  lips that gave wings. Alone must seek ether.  And alone without nest shall eagle fly across sun.  *****  Now when reached foot hill, turned again towards sea, saw ship approaching harbour, upon her prow mariners, men own land.  And soul cried out them, he said:  Sons my ancient mother, riders of tides,  How often have sailed my dreams. And now come my awakening, which is my deeper dream.  Ready am I go, my eagerness with sails full awaits wind.  Only another breath will I breathe in this still air, only another loving look cast backward,  And then I shall stand among you, seafarer among seafarers.  you, vast sea, sleepless mother,  Who alone peace freedom river stream,  Only another winding will stream make, only another murmur glade,  And then shall I come you, boundless drop boundless ocean.  *****  And as walked saw afar men women leaving their fields their vineyards hastening towards city gates.  And heard their voices calling his name, shouting field field telling one another coming his ship.  And said himself:  Shall day parting be day of gathering?  And shall be said that my eve was in truth my dawn?  And what shall I unto him who has left plough midfurrow, to him who has stopped wheel his winepress?  my heart become tree heavy-laden fruit that I may gather unto them?  And shall my desires flow like fountain that I fill their cups?  Am I harp that hand mighty may touch me, flute that breath may pass through me?  A seeker silences am I, what treasure have I found silences that I may dispense confidence?  If my day harvest, what fields have I sowed seed, in what unremembered seasons?  If indeed be hour which I lift up my lantern, my flame that shall burn therein.  Empty dark shall I raise my lantern,  And guardian night shall fill it oil shall light also.  *****  These things said words. But much in heart remained unsaid.  speak deeper secret.  *****  [Illustration: 0020]  And when entered into city all people meet him, they were crying out him as one voice.  And elders city stood forth said:  Go yet us.  A noontide have been our twilight, your youth has given us dreams dream.  No stranger among us, nor guest, our son our dearly beloved.  Suffer yet our eyes hunger for your face.  *****  And priests priestesses said unto him:  Let waves sea separate us now, years have spent our midst become memory.  You have walked among us spirit,  your shadow has been light upon our faces.  Much have we loved you. But speechless was our love, veils has been veiled.  Yet now cries aloud unto you, would stand revealed you.  And ever has been that love knows not its own depth until hour of separation.  *****  And others also entreated him. But answered them not. He only bent his head; who stood near saw his tears falling upon breast.  An ...
