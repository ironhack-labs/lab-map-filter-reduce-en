# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources in the README.md file
# - Happy learning!

# %%
# Import reduce from functools, numpy and pandas
from functools import reduce
import numpy
import pandas

# %% [markdown]
# # Challenge 1 - Mapping
#
# #### We will use the map function to clean up words in a book.
#
# In the following cell, we will read a text file containing the book The Prophet by Khalil Gibran.

# %%
# Run this code:

location = '../data/58585-0.txt'
with open(location, 'r', encoding="utf8") as f:
    prophet = f.read().split(' ')

# %%
len(prophet)
# Out:
# 13637

# %% [markdown]
# #### Let's remove the first 568 words since they contain information about the book but are not part of the book itself.
#
# Do this by removing from `prophet` elements 0 through 567 of the list (you can also do this by keeping elements 568 through the last element).

# %%
# your code here

# Remove the first 568 elements from the list
prophet = prophet[568:]

# Check the new length of the list to ensure it's correct
len(prophet)
# Out:
# 13069

# %% [raw]
# Explanation of the Code:
#
# 1. Removing the first 568 elements:
#
#     prophet = prophet[568:]
#
#     * The prophet list contains words from the book, but the first 568 elements are
# metadata (e.g., title, author, licensing information) that are not part of the book's main content.
#     * We use Python's slicing syntax list[start:end] to create a new list that starts at index 568 and goes to the end. By omitting the end parameter, Python automatically includes all elements from index 568 to the last element.
#
# 2. Checking the new length:
#
#     len(prophet)
#
#     * The len() function is used to check the number of elements in the list prophet after removing the metadata.
#     * This helps verify that the slicing operation was successful and gives us the updated word count of the relevant content.

# %% [markdown]
# If you look through the words, you will find that many words have a reference attached to them. For example, let's look at words 1 through 10.

# %%
# your code here

# Display words 1 through 10 from the `prophet` list
prophet[:10]
# Out:
# ['PROPHET\n\n|Almustafa,',
#  'the{7}',
#  'chosen',
#  'and',
#  'the\nbeloved,',
#  'who',
#  'was',
#  'a',
#  'dawn',
#  'unto']

# %% [raw]
# Explanation:
#
# 1. Accessing a range of elements:
#
#     * The code uses slicing to access the first 10 elements of the prophet list.
#     * The syntax list[start:end] retrieves elements starting from start (inclusive) up to, but not including, end.
#     * Here, :10 is shorthand for 0:10, so it starts from the first element (index 0) and goes up to the 10th element (index 9).
#
# 2. Why check words 1–10?
#
#     * This gives a quick look at the first few words in the text after removing the metadata.
#     * It's useful for observing patterns in the words, like unnecessary references, punctuation, or formatting issues that might need cleaning.

# %% [raw]
# The output suggests that some of the words in the text include unwanted artifacts like {7} and \n, which are references or formatting characters not part of the main text. Here's what you can do next to clean the data:
#
# Observations from the Output:
#
# 1. References in curly braces ({7}): These are likely page or line numbers and should be removed.
# 2. Newline characters (\n): These indicate line breaks in the text and can be stripped.
# 3. Punctuation or special characters (e.g., |, ,): Depending on your goals, these may also need cleaning.

# %% [markdown]
# #### The next step is to create a function that will remove references.
#
# We will do this by splitting the string on the `{` character and keeping only the part before this character. Write your function below.

# %%
def reference(x):
    '''
    Input: A string
    Output: The string with references removed
    
    Example:
    Input: 'the{7}'
    Output: 'the'
    '''
    
    # your code here

    #Split the string at the '{' character
    parts = x.split('{')

    #Return the part before the '{' (i.e., the first part of the split)
    return parts[0]

# %% [raw]
# Explanation:
#
# 1. Splitting the string:
#
#     * The split('{') function splits the string wherever it encounters the { character.
#     * For example: 'the{7}' becomes ['the', '7}'].
#
# 2. Keeping the first part:
#
#     * The part before { (i.e., parts[0]) is the portion we want, so we return it.
#     * For 'the{7}', parts[0] is 'the'.
#
# 3. Handling strings without {:
#
#     * If there’s no { in the string, split will return the entire string as a single element list.
#     * For example, 'chosen' will remain as ['chosen'], and parts[0] is 'chosen'.
#
# This function will work for all words, regardless of whether they have references. Let me know if you want to test it or apply it to the list!

# %%
# your code here

# %% [markdown]
# Now that we have our function, use the `map()` function to apply this function to our book, The Prophet. Return the resulting list to a new list called `prophet_reference`.

# %%
# your code here

# Use map() to apply the reference function to each word in the prophet list
prophet_reference = list(map(reference, prophet))

# Check the first 10 words from the prophet_reference list to verify
prophet_reference[:10]
# Out:
# ['PROPHET\n\n|Almustafa,',
#  'the',
#  'chosen',
#  'and',
#  'the\nbeloved,',
#  'who',
#  'was',
#  'a',
#  'dawn',
#  'unto']

# %% [raw]
# Explanation:
#
# 1. map(reference, prophet):
#
#     * The map() function applies the reference function to each element (word) in the prophet list.
#     * map() returns an iterator, so we convert it to a list using list().
#
# 2. Checking the cleaned output:
#
# * After applying the function, we check the first 10 words in the cleaned list (prophet_cleaned[:10]) to verify that the references have been removed.
#
# This should clean up the words by removing any references (i.e., anything inside {}).

# %% [markdown]
# Another thing you may have noticed is that some words contain a line break. Let's write a function to split those words. Our function will return the string split on the character `\n`. Write your function in the cell below.

# %%
def line_break(x):
    '''
    Input: A string
    Output: A list of strings split on the line break (\n) character
        
    Example:
    Input: 'the\nbeloved'
    Output: ['the', 'beloved']
    '''
    
    # your code here
    
    # Split the string on the newline character (\n)
    return x.split('\n')

# %% [raw]
# Explanation:
#
# 1. Splitting on \n:
#
#     * The split('\n') method splits the input string into a list of substrings wherever it encounters the newline character \n.
#     * For example, 'the\nbeloved' becomes ['the', 'beloved'].
#
# 2. Handling strings without \n:
#
#     * If the input string does not contain \n, the split() function will return a list with the original string as its only element.
#     * For example, 'chosen' becomes ['chosen'].

# %% [markdown]
# Apply the `line_break` function to the `prophet_reference` list. Name the new list `prophet_line`.

# %%
# your code here

# Apply the line_break function to each word in the prophet_reference list
prophet_line = list(map(line_break, prophet_reference))

# Check the first 10 elements in prophet_line to verify
prophet_line[:10]
# Out:
# [['PROPHET', '', '|Almustafa,'],
#  ['the'],
#  ['chosen'],
#  ['and'],
#  ['the', 'beloved,'],
#  ['who'],
#  ['was'],
#  ['a'],
#  ['dawn'],
#  ['unto']]

# %% [raw]
# Explanation:
#
# 1. Using map():
#
#     * The line_break function is applied to each word in the prophet_reference list using map().
#     * Each word is transformed into a list of substrings split on the newline character (\n).
#
# 2. Converting to a list:
#
#     * The result of map() is an iterator, so we convert it to a list using list().
#
# 3. Resulting structure:
#
#     * Each element in prophet_line will now be a list. For example:
#         * 'the\nbeloved' becomes ['the', 'beloved'].
#         * 'chosen' becomes ['chosen'].
#
# 4. Verify the output:
#
#     * Checking the first few elements of prophet_line ensures that the function is working as expected.

# %% [markdown]
# If you look at the elements of `prophet_line`, you will see that the function returned lists and not strings. Our list is now a list of lists. Flatten the list using list comprehension. Assign this new list to `prophet_flat`.

# %%
prophet_flat = [i for sub in prophet_line for i in sub]
prophet_flat
# Out:
# ['PROPHET',
#  '',
#  '|Almustafa,',
#  'the',
#  'chosen',
#  'and',
#  'the',
#  'beloved,',
#  'who',
#  'was',
#  'a',
#  'dawn',
#  'unto',
#  'his',
#  'own',
#  'day,',
#  'had',
#  'waited',
#  'twelve',
#  'years',
#  'in',
#  'the',
#  'city',
#  'of',
#  'Orphalese',
#  'for',
#  'his',
#  'ship',
#  'that',
#  'was',
#  'to',
#  'return',
#  'and',
#  'bear',
#  'him',
#  'back',
#  'to',
#  'the',
#  'isle',
#  'of',
#  'his',
#  'birth.',
#  '',
#  'And',
#  'in',
#  'the',
#  'twelfth',
#  'year,',
#  'on',
#  'the',
#  'seventh',
#  'day',
#  'of',
#  'Ielool,',
#  'the',
#  'month',
#  'of',
#  'reaping,',
#  'he',
#  'climbed',
#  'the',
#  'hill',
#  'without',
#  'the',
#  'city',
#  'walls',
#  'and',
#  'looked',
#  'seaward;',
#  'and',
#  'he',
#  'beheld',
#  'his',
#  'ship',
#  'coming',
#  'with',
#  'the',
#  'mist.',
#  '',
#  'Then',
#  'the',
#  'gates',
#  'of',
#  'his',
#  'heart',
#  'were',
#  'flung',
#  'open,',
#  'and',
#  'his',
#  'joy',
# ...

# %%
# your code here

# %% [raw]
# Explanation:
#
# 1. List comprehension:
#
#     * This is a compact way to iterate through and process nested lists.
#
# 2. Outer loop (for sub in prophet_line):
#
#     * Iterates through each sublist (sub) in the prophet_line list.
#
# 3. Inner loop (for i in sub):
#
#     * Iterates through each element (i) within the current sublist (sub).
#
# 4. Building the flat list:
#
#     * Combines all elements from the inner loop into a single list, effectively flattening the nested structure.

# %% [markdown]
# # Challenge 2 - Filtering
#
# When printing out a few words from the book, we see that there are words that we may not want to keep if we choose to analyze the corpus of text. Below is a list of words that we would like to get rid of. Create a function that will return false if it contains a word from the list of words specified and true otherwise.

# %%
def word_filter(x):
    '''
    Input: A string
    Output: True if the word is not in the specified list 
    and False if the word is in the list.
        
    Example:
    word list = ['and', 'the']
    Input: 'and'
    Output: False
    
    Input: 'John'
    Output: True
    '''
    
    word_list = ['and', 'the', 'a', 'an']
    
    # your code here

     # Return False if the word is in the word_list, otherwise True
    return x not in word_list

# %% [raw]
# Explanation:
#
# 1. Word list:
#
#     * word_list = ['and', 'the', 'a', 'an'] contains the words I want to filter out.
#
# 2. Check membership:
#
#     * x not in word_list checks if the input word x is not in the list:
#         * If x is in word_list, the function returns False.
#         * If x is not in word_list, the function returns True.
#
# 3. Why return True or False?
#
#     * This logic ensures that only words not in the list are retained when the function is applied as a filter.

# %% [markdown]
# Use the `filter()` function to filter out the words speficied in the `word_filter()` function. Store the filtered list in the variable `prophet_filter`.

# %%
# your code here

# Apply the word_filter function to prophet_flat using filter()
prophet_filter = list(filter(word_filter, prophet_flat))

# Check the first 10 filtered words
prophet_filter[:10]
# Out:
# ['PROPHET',
#  '',
#  '|Almustafa,',
#  'chosen',
#  'beloved,',
#  'who',
#  'was',
#  'dawn',
#  'unto',
#  'his']

# %% [raw]
# Explanation:
#
# 1. Using filter():
#
#     * filter(word_filter, prophet_flat) applies the word_filter() function to each element of the prophet_flat list.
#     * The filter() function keeps only those elements for which word_filter() returns True.
#
# 2. Converting to a list:
#
#     * filter() returns a filter object, so we convert it into a list using list().
#
# 3. Filtered list:
#
#     * The resulting prophet_filter list contains all words from prophet_flat, excluding the ones specified in the word_list inside word_filter().
#
# 4. Verification:
#
#     * Displaying the first 10 words of prophet_filter ensures the filtering worked as expected.

# %% [markdown]
# # Bonus Challenge
#
# Rewrite the `word_filter` function above to not be case sensitive.

# %%
def word_filter_case(x):

    #I'm adding these red comments:
    
    '''
    Input: A string
    Output: True if the word is not in the specified list (case-insensitive)
    and False if the word is in the list.
        
    Example:
    word list = ['and', 'the', 'a', 'an']
    Input: 'AND'
    Output: False
    
    Input: 'John'
    Output: True
    '''
    # List of words to filter out (I added this comment)
    word_list = ['and', 'the', 'a', 'an']

    # your code here
    
    # Convert the input word to lowercase and check if it's in the lowercase word_list
    return x.lower() not in word_list

# %%
# I added this:

# Test list of words with mixed cases
test_words = ['AND', 'the', 'A', 'An', 'John', 'love', 'Friend']

# Apply the word_filter_case function to the test list
filtered_test = list(filter(word_filter_case, test_words))

# Print the filtered result
print(filtered_test)
# Out:
# ['John', 'love', 'Friend']

# %% [markdown]
# Explanation:
#
# 1. Case normalization:
#
#     * x.lower() converts the input word x to lowercase to ensure case-insensitivity.
#
# 2. Membership check:
#
#     * The lowercase word x.lower() is checked against the word_list (which contains only lowercase words).
#
# 3. Return value:
#
#     * If the lowercase word is not in the word_list, the function returns True (keep the word).
#     * If it is in the word_list, the function returns False (filter it out).

# %% [markdown]
# # Challenge 3 - Reducing
#
# #### Now that we have significantly cleaned up our text corpus, let's use the `reduce()` function to put the words back together into one long string separated by spaces.
#
# We will start by writing a function that takes two strings and concatenates them together with a space between the two strings.

# %%
def concat_space(a, b):
    '''
    Input:Two strings
    Output: A single string separated by a space
        
    Example:
    Input: 'John', 'Smith'
    Output: 'John Smith'
    '''
    
    # your code here

    # Concatenate the two strings with a space in between
    return a + ' ' + b

# %% [raw]
# Explanation:
#
# 1. String concatenation:
#
#     * a + ' ' + b joins the two input strings a and b with a space ' ' in between.
#     * For example:
#         * If a = 'John' and b = 'Smith', the result will be 'John Smith'.
#
# 2. General case:
#
#     * This function works for any two strings, ensuring they are combined with a space.

# %%
# your code here

# %% [markdown]
# Use the function above to reduce the text corpus in the list `prophet_filter` into a single string. Assign this new string to the variable `prophet_string`.

# %%
# your code here

from functools import reduce

# Use reduce to concatenate the words in prophet_filter with spaces
prophet_string = reduce(concat_space, prophet_filter)

# Check the first 100 characters of the resulting string
print(prophet_string[:100])
# Out:
# PROPHET  |Almustafa, chosen beloved, who was dawn unto his own day, had waited twelve years in city

# %% [raw]
# Explanation:
#
# * Using reduce():
#
#     * The reduce() function applies the concat_space function to all elements in the prophet_filter list, effectively concatenating them into one single string with spaces in between.
#
# * Result:
#
#     * The variable prophet_string will hold the final concatenated string of the entire text corpus, and using print(prophet_string[:100]) allows me to view the first 100 characters for verification.
